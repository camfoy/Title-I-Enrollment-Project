# %% [markdown]
# # AUSTINSCHOOLS.PY
# #### Create the CSV with data from the GreatSchools.org web APIs
# #### author : suchita mujumdar

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import xmltodict

# GreatSchools API Key
from keys import api_keys

# %%
f = open('output/fieldErrors.txt','w')
def extract(mydict, field):
    try:
        return mydict[field]
    except Exception as e:
        f.write("extract{}: {}".format(type(e), e))
        return np.nan

# %%
def extract_ethnicity(ethnicity_data, ethnicity):
    try:
        for x in ethnicity_data:
            if x["name"] == ethnicity:
                return x["value"]
    except Exception as e:
        f.write("extract_ethnicity {}: {}".format(type(e), e))
        return np.nan

# %%
def get_census_data(gsId):   
    census_url = "https://api.greatschools.org/school/census/TX/{0}?key={1}".format(gsId,api_keys.gs_key)
    census = xmltodict.parse(requests.get(census_url).content)['census-data']
    return census

# %%
def get_schools(school_type):
    base_url = "https://api.greatschools.org/schools/TX/Austin/{0}?key={1}&limit=-1&sort=parent_rating".format(school_type, api_keys.gs_key)
    schools = xmltodict.parse(requests.get(base_url).content)['schools']
    df = pd.DataFrame(schools, columns=schools.keys())
    return df

# %%
df_public = get_schools("public")
df_private = get_schools("private")
df_charter = get_schools("charter")
df = df_public.append(df_private)
df = df.append(df_charter)

# %%
school_data = ['gsId', 'name', 'type','gradeRange','enrollment','gsRating','parentRating','city','state',\
    'districtId','district','districtNCESId','address','phone','fax','website','ncesId','lat',\
    'lon']
for field in school_data:
    df[field] = df.school.map(lambda x: extract(x, field))

# %%
df.iloc[0]
# Out:
# school            {'gsId': '527', 'name': 'Blackshear Elementary...
# gsId                                                            527
# name                                   Blackshear Elementary School
# type                                                         public
# gradeRange                                                     PK-5
# enrollment                                                      302
# gsRating                                                          8
# parentRating                                                      5
# city                                                         Austin
# state                                                            TX
# districtId                                                      115
# district                         Austin Independent School District
# districtNCESId                                              4808940
# address                  1712 East 11th Street, \nAustin, TX  78702
# phone                                                (512) 414-2021
# fax                                                  (512) 477-7640
# website                     http://www.blackshearyellowjackets.org/
# ncesId                                                 480894000300
# lat                                                       30.266968
# lon                                                       -97.72217
# Name: 0, dtype: object

# %%
df.head()
# Out:
#                                               school gsId  \
# 0  {'gsId': '527', 'name': 'Blackshear Elementary...  527
# 1  {'gsId': '532', 'name': 'Bryker Woods Elementa...  532
# 2  {'gsId': '535', 'name': 'Casis Elementary Scho...  535
# 3  {'gsId': '557', 'name': 'Maplewood Elementary ...  557
# 4  {'gsId': '559', 'name': 'Mathews Elementary Sc...  559
#
#                              name    type gradeRange enrollment gsRating  \
# 0    Blackshear Elementary School  public       PK-5        302        8
# 1  Bryker Woods Elementary School  public       PK-6        400        9
# 2         Casis Elementary School  public       PK-5        793       10
# 3     Maplewood Elementary School  public       PK-6        480        4
# 4       Mathews Elementary School  public       PK-6        425        8
#
#   parentRating    city state districtId                            district  \
# 0            5  Austin    TX        115  Austin Independent School District
# 1            5  Austin    TX        115  Austin Independent School District
# 2            5  Austin    TX        115  Austin Independent School District
# 3            5  Austin    TX        115  Austin Independent School District
# 4            5  Austin    TX        115  Austin Independent School District
#
#   districtNCESId                                         address  \
# 0        4808940      1712 East 11th Street, \nAustin, TX  78702
# 1        4808940           3309 Kerbey Lane, \nAustin, TX  78703
# 2        4808940  2710 Exposition Boulevard, \nAustin, TX  78703
# 3        4808940      3808 Maplewood Avenue, \nAustin, TX  78722
# 4        4808940       906 West Lynn Street, \nAustin, TX  78703
#
#             phone             fax                                  website  \
# 0  (512) 414-2021  (512) 477-7640  http://www.blackshearyellowjackets.org/
# 1  (512) 414-2054  (512) 459-9047              https://brykerwoodspta.org/
# 2  (512) 414-2062  (512) 477-1776              http://casiselementary.com/
# 3  (512) 414-4402  (512) 472-8559              www.maplewoodelementary.com
# 4  (512) 414-4406  (512) 476-2108              https://www.mathews360.com/
#
#          ncesId        lat         lon
# 0  480894000300  30.266968   -97.72217
# 1  480894000305  30.304869  -97.750626
# 2  480894000308  30.304344   -97.76505
# 3  480894000330  30.293337  -97.714905
# 4  480894000332  30.278215  -97.760796

# %%
df["census"] = df["gsId"].apply(get_census_data)

# %%
df['census'][0]
# Out:
# OrderedDict([('schoolName', 'Blackshear Elementary School'),
#              ('address', '1712 East 11th Street,  Austin, TX  78702'),
#              ('latitude', '30.266968'),
#              ('longitude', '-97.72217'),
#              ('phone', '(512) 414-2021'),
#              ('type', 'public'),
#              ('district', 'Austin Independent School District'),
#              ('headOfficialName', 'MR RICHARD GARNER'),
#              ('enrollment', '302'),
#              ('freeAndReducedPriceLunch', '81.1'),
#              ('ethnicities',
#               OrderedDict([('ethnicity',
#                             [OrderedDict([('name', 'White, non-Hispanic'),
#                                           ('value', '9.97'),
#                                           ('year', '2016')]),
#                              OrderedDict([('name', 'Black, non-Hispanic'),
#                                           ('value', '27.84'),
#                                           ('year', '2016')]),
#                              OrderedDict([('name', 'Hispanic'),
#                                           ('value', '57.39'),
#                                           ('year', '2016')]),
#                              OrderedDict([('name', 'Multiracial'),
#                                           ('value', '3.09'),
#                                           ('year', '2016')]),
#                              OrderedDict([('name', 'Asian'),
#                                           ('value', '0.69'),
#                                           ('year', '2016')]),
#                              OrderedDict([('name',
#                                            'Native American or Native Alaskan'),
#                                           ('value', '1.03'),
#                                           ('year', '2016')]),
#                              OrderedDict([('name',
#                                            'Native Hawaiian or Other Pacific Islander'),
#                                           ('value', '0.0'),
#                                           ('year', '2016')])])])),
#              ('idea', '8.4'),
#              ('plan504', '4.2'),
#              ('percentTeachersInFirstSecondYear', '15')])

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#                                               school gsId  \
# 0  {'gsId': '527', 'name': 'Blackshear Elementary...  527
# 1  {'gsId': '532', 'name': 'Bryker Woods Elementa...  532
# 2  {'gsId': '535', 'name': 'Casis Elementary Scho...  535
# 3  {'gsId': '557', 'name': 'Maplewood Elementary ...  557
# 4  {'gsId': '559', 'name': 'Mathews Elementary Sc...  559
#
#                              name    type gradeRange enrollment gsRating  \
# 0    Blackshear Elementary School  public       PK-5        302        8
# 1  Bryker Woods Elementary School  public       PK-6        400        9
# 2         Casis Elementary School  public       PK-5        793       10
# 3     Maplewood Elementary School  public       PK-6        480        4
# 4       Mathews Elementary School  public       PK-6        425        8
#
#   parentRating    city state  ...                            district  \
# 0            5  Austin    TX  ...  Austin Independent School District
# 1            5  Austin    TX  ...  Austin Independent School District
# 2            5  Austin    TX  ...  Austin Independent School District
# 3            5  Austin    TX  ...  Austin Independent School District
# 4            5  Austin    TX  ...  Austin Independent School District
#
#   districtNCESId                                         address  \
# 0        4808940      1712 East 11th Street, \nAustin, TX  78702
# 1        4808940           3309 Kerbey Lane, \nAustin, TX  78703
# 2        4808940  2710 Exposition Boulevard, \nAustin, TX  78703
# 3        4808940      3808 Maplewood Avenue, \nAustin, TX  78722
# 4        4808940       906 West Lynn Street, \nAustin, TX  78703
#
#             phone             fax                                  website  \
# 0  (512) 414-2021  (512) 477-7640  http://www.blackshearyellowjackets.org/
# 1  (512) 414-2054  (512) 459-9047              https://brykerwoodspta.org/
# 2  (512) 414-2062  (512) 477-1776              http://casiselementary.com/
# 3  (512) 414-4402  (512) 472-8559              www.maplewoodelementary.com
# 4  (512) 414-4406  (512) 476-2108              https://www.mathews360.com/
#
#          ncesId        lat         lon  \
# 0  480894000300  30.266968   -97.72217
# 1  480894000305  30.304869  -97.750626
# 2  480894000308  30.304344   -97.76505
# 3  480894000330  30.293337  -97.714905
# 4  480894000332  30.278215  -97.760796
#
#                                               census
# 0  {'schoolName': 'Blackshear Elementary School',...
# 1  {'schoolName': 'Bryker Woods Elementary School...
# 2  {'schoolName': 'Casis Elementary School', 'add...
# 3  {'schoolName': 'Maplewood Elementary School', ...
# 4  {'schoolName': 'Mathews Elementary School', 'a...
#
# [5 rows x 21 columns]

# %%
del(df['index'])

# %%
df["census"] = df["gsId"].apply(get_census_data)

# %%
census_data = ['schoolName', "district",'address', 'latitude','longitude','phone','type','headOfficialName',\
    'enrollment','freeAndReducedPriceLunch','idea','plan504','percentTeachersInFirstSecondYear','ethnicities']
for field in census_data:
    df[field] = df.census.map(lambda x: extract(x, field))

# %%
df.head()
# Out:
#                                               school gsId  \
# 0  {'gsId': '527', 'name': 'Blackshear Elementary...  527
# 1  {'gsId': '532', 'name': 'Bryker Woods Elementa...  532
# 2  {'gsId': '535', 'name': 'Casis Elementary Scho...  535
# 3  {'gsId': '557', 'name': 'Maplewood Elementary ...  557
# 4  {'gsId': '559', 'name': 'Mathews Elementary Sc...  559
#
#                              name    type gradeRange enrollment gsRating  \
# 0    Blackshear Elementary School  public       PK-5        302        8
# 1  Bryker Woods Elementary School  public       PK-6        400        9
# 2         Casis Elementary School  public       PK-5        793       10
# 3     Maplewood Elementary School  public       PK-6        480        4
# 4       Mathews Elementary School  public       PK-6        425        8
#
#   parentRating    city state  ...  \
# 0            5  Austin    TX  ...
# 1            5  Austin    TX  ...
# 2            5  Austin    TX  ...
# 3            5  Austin    TX  ...
# 4            5  Austin    TX  ...
#
#                                               census  \
# 0  {'schoolName': 'Blackshear Elementary School',...
# 1  {'schoolName': 'Bryker Woods Elementary School...
# 2  {'schoolName': 'Casis Elementary School', 'add...
# 3  {'schoolName': 'Maplewood Elementary School', ...
# 4  {'schoolName': 'Mathews Elementary School', 'a...
#
#                        schoolName   latitude   longitude  \
# 0    Blackshear Elementary School  30.266968   -97.72217
# 1  Bryker Woods Elementary School  30.304869  -97.750626
# 2         Casis Elementary School  30.304344   -97.76505
# 3     Maplewood Elementary School  30.293337  -97.714905
# 4       Mathews Elementary School  30.278215  -97.760796
#
#        headOfficialName freeAndReducedPriceLunch  idea plan504  \
# 0     MR RICHARD GARNER                     81.1   8.4     4.2
# 1  MS KRISTINA MUEHLING                     9.75   6.1     4.2
# 2      MR SAMUEL TINNON                     2.14   6.2     6.1
# 3    MS VICKIE JACOBSON                    43.07  10.5       6
# 4    G MARTINO-BREWSTER                     36.0   4.4     4.2
#
#   percentTeachersInFirstSecondYear  \
# 0                               15
# 1                              3.8
# 2                              5.9
# 3                              6.7
# 4                              3.6
#
#                                          ethnicities
# 0  {'ethnicity': [{'name': 'White, non-Hispanic',...
# 1  {'ethnicity': [{'name': 'White, non-Hispanic',...
# 2  {'ethnicity': [{'name': 'White, non-Hispanic',...
# 3  {'ethnicity': [{'name': 'White, non-Hispanic',...
# 4  {'ethnicity': [{'name': 'White, non-Hispanic',...
#
# [5 rows x 30 columns]

# %%
df['ethnicity'] = df['ethnicities'].map(lambda x: extract(x, 'ethnicity'))
df.iloc[0]
# Out:
# school                              {'gsId': '527', 'name': 'Blackshear Elementary...
# gsId                                                                              527
# name                                                     Blackshear Elementary School
# type                                                                           public
# gradeRange                                                                       PK-5
# enrollment                                                                        302
# gsRating                                                                            8
# parentRating                                                                        5
# city                                                                           Austin
# state                                                                              TX
# districtId                                                                        115
# district                                           Austin Independent School District
# districtNCESId                                                                4808940
# address                                     1712 East 11th Street,  Austin, TX  78702
# phone                                                                  (512) 414-2021
# fax                                                                    (512) 477-7640
# website                                       http://www.blackshearyellowjackets.org/
# ncesId                                                                   480894000300
# lat                                                                         30.266968
# lon                                                                         -97.72217
# census                              {'schoolName': 'Blackshear Elementary School',...
# schoolName                                               Blackshear Elementary School
# latitude                                                                    30.266968
# longitude                                                                   -97.72217
# headOfficialName                                                    MR RICHARD GARNER
# freeAndReducedPriceLunch                                                         81.1
# idea                                                                              8.4
# plan504                                                                           4.2
# percentTeachersInFirstSecondYear                                                   15
# ethnicities                         {'ethnicity': [{'name': 'White, non-Hispanic',...
# ethnicity                           [{'name': 'White, non-Hispanic', 'value': '9.9...
# Name: 0, dtype: object

# %%
ethnicities = ['White, non-Hispanic', 'Black, non-Hispanic', 'Hispanic','Multiracial',\
        'Asian','Native American or Native Alaskan','Native Hawaiian or Other Pacific Islander']
for ethnicity in ethnicities:
    df[ethnicity] = df.ethnicity.map(lambda x: extract_ethnicity(x, ethnicity))

# %%
df.iloc[0]
# Out:
# school                                       {'gsId': '527', 'name': 'Blackshear Elementary...
# gsId                                                                                       527
# name                                                              Blackshear Elementary School
# type                                                                                    public
# gradeRange                                                                                PK-5
# enrollment                                                                                 302
# gsRating                                                                                     8
# parentRating                                                                                 5
# city                                                                                    Austin
# state                                                                                       TX
# districtId                                                                                 115
# district                                                    Austin Independent School District
# districtNCESId                                                                         4808940
# address                                              1712 East 11th Street,  Austin, TX  78702
# phone                                                                           (512) 414-2021
# fax                                                                             (512) 477-7640
# website                                                http://www.blackshearyellowjackets.org/
# ncesId                                                                            480894000300
# lat                                                                                  30.266968
# lon                                                                                  -97.72217
# census                                       {'schoolName': 'Blackshear Elementary School',...
# schoolName                                                        Blackshear Elementary School
# latitude                                                                             30.266968
# longitude                                                                            -97.72217
# headOfficialName                                                             MR RICHARD GARNER
# freeAndReducedPriceLunch                                                                  81.1
# idea                                                                                       8.4
# plan504                                                                                    4.2
# percentTeachersInFirstSecondYear                                                            15
# ethnicities                                  {'ethnicity': [{'name': 'White, non-Hispanic',...
# ethnicity                                    [{'name': 'White, non-Hispanic', 'value': '9.9...
# White, non-Hispanic                                                                       9.97
# Black, non-Hispanic                                                                      27.84
# Hispanic                                                                                 57.39
# Multiracial                                                                               3.09
# Asian                                                                                     0.69
# Native American or Native Alaskan                                                         1.03
# Native Hawaiian or Other Pacific Islander                                                  0.0
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['school', 'gsId', 'name', 'type', 'gradeRange', 'enrollment',
#        'gsRating', 'parentRating', 'city', 'state', 'districtId', 'district',
#        'districtNCESId', 'address', 'phone', 'fax', 'website', 'ncesId', 'lat',
#        'lon', 'census', 'schoolName', 'latitude', 'longitude',
#        'headOfficialName', 'freeAndReducedPriceLunch', 'idea', 'plan504',
#        'percentTeachersInFirstSecondYear', 'ethnicities', 'ethnicity',
#        'White, non-Hispanic', 'Black, non-Hispanic', 'Hispanic', 'Multiracial',
#        'Asian', 'Native American or Native Alaskan',
#        'Native Hawaiian or Other Pacific Islander'],
#       dtype='object')

# %%
df = df[[ 'gsId', 'name', 'type', 'gradeRange', 'enrollment',
       'gsRating', 'parentRating', 'city', 'state', 'districtId', 'district',
       'districtNCESId', 'address', 'phone', 'fax', 'website', 'ncesId', 'lat',
       'lon', 'schoolName', 'latitude', 'longitude',
       'headOfficialName', 'freeAndReducedPriceLunch', 'idea', 'plan504',
       'percentTeachersInFirstSecondYear', 
       'White, non-Hispanic', 'Black, non-Hispanic', 'Hispanic', 'Multiracial',
       'Asian', 'Native American or Native Alaskan',
       'Native Hawaiian or Other Pacific Islander' ]]

# %%
df.head()
# Out:
#   gsId                            name    type gradeRange enrollment gsRating  \
# 0  527    Blackshear Elementary School  public       PK-5        302        8
# 1  532  Bryker Woods Elementary School  public       PK-6        400        9
# 2  535         Casis Elementary School  public       PK-5        793       10
# 3  557     Maplewood Elementary School  public       PK-6        480        4
# 4  559       Mathews Elementary School  public       PK-6        425        8
#
#   parentRating    city state districtId  ...  idea plan504  \
# 0            5  Austin    TX        115  ...   8.4     4.2
# 1            5  Austin    TX        115  ...   6.1     4.2
# 2            5  Austin    TX        115  ...   6.2     6.1
# 3            5  Austin    TX        115  ...  10.5       6
# 4            5  Austin    TX        115  ...   4.4     4.2
#
#   percentTeachersInFirstSecondYear White, non-Hispanic Black, non-Hispanic  \
# 0                               15                9.97               27.84
# 1                              3.8               68.25                1.75
# 2                              5.9               79.32                1.26
# 3                              6.7                38.1               17.97
# 4                              3.6                44.0                5.18
#
#   Hispanic Multiracial Asian Native American or Native Alaskan  \
# 0    57.39        3.09  0.69                              1.03
# 1    20.75         5.0   4.0                              0.25
# 2    10.84        5.17  3.15                              0.13
# 3    33.55        8.23  2.16                               0.0
# 4    35.76        5.65  8.94                              0.24
#
#   Native Hawaiian or Other Pacific Islander
# 0                                       0.0
# 1                                       0.0
# 2                                      0.13
# 3                                       0.0
# 4                                      0.24
#
# [5 rows x 34 columns]

# %%
df.to_csv("data/AustinSchools.csv")

# %%
# !open 'data/AustinSchools.csv'
